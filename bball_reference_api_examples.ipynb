# %%
from basketball_reference_web_scraper import client
from basketball_reference_web_scraper.data import Team
import pandas as pd
from develop import NBAPlayers, NBAParser
import requests
from bs4 import BeautifulSoup
from selenium import webdriver
import time
from settings import set_basic_logging
# Out:
# C:\Users\rivverg\Anaconda3\envs\basketball-reference-scraping\lib\site-packages\requests\__init__.py:89: RequestsDependencyWarning: urllib3 (1.26.11) or chardet (3.0.4) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({}) doesn't match a supported "

# %%
set_basic_logging(level=20)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [3], in <cell line: 1>()
# ----> 1 set_basic_logging(level=20)
#
# File ~\DontBeABitch\Projects\My Shit\basketball-betting-ml\src\settings.py:24, in set_basic_logging(format_str, log_warnings, level)
#      22 def set_basic_logging(format_str: str = DEFAULT_LOG_FORMAT, log_warnings: bool = True, level: int = None):
#      23     logging.captureWarnings(log_warnings)
# ---> 24     logging.basicConfig(
#      25         level=level if level else int(os.getenv("LOGGING_LEVEL", logging.WARNING)),
#      26         stream=sys.stdout,
#      27         format=format_str,
#      28         datefmt="%Y-%m-%d %H-%M-%S",
#      29     )
#
# File ~\Anaconda3\envs\basketball-reference-scraping\lib\logging\__init__.py:1999, in basicConfig(**kwargs)
#    1996     raise ValueError('Style must be one of: %s' % ','.join(
#    1997                      _STYLES.keys()))
#    1998 fs = kwargs.pop("format", _STYLES[style][1])
# -> 1999 fmt = Formatter(fs, dfs, style)
#    2000 for h in handlers:
#    2001     if h.formatter is None:
#
# File ~\Anaconda3\envs\basketball-reference-scraping\lib\logging\__init__.py:580, in Formatter.__init__(self, fmt, datefmt, style, validate)
#     578 self._style = _STYLES[style][0](fmt)
#     579 if validate:
# --> 580     self._style.validate()
#     582 self._fmt = self._style._fmt
#     583 self.datefmt = datefmt
#
# File ~\Anaconda3\envs\basketball-reference-scraping\lib\logging\__init__.py:432, in PercentStyle.validate(self)
#     430 def validate(self):
#     431     """Validate the input format, ensure it matches the correct style"""
# --> 432     if not self.validation_pattern.search(self._fmt):
#     433         raise ValueError("Invalid format '%s' for '%s' style" % (self._fmt, self.default_format[0]))
#
# TypeError: expected string or bytes-like object

# %%
mvps = []
for year in list(range(1991, 2023)):
    parser = NBAParser(year=year)
    mvps.append(parser.parse_player_mvp_voting_html())
    
df = pd.concat(mvps)

# %%
pg = []
for year in list(range(1991, 2023)):
    parser = NBAParser(year=year)
    parser.parse_player_per_game_data()

# df = pd.concat(pg)

# %%
parser = NBAParser(year=2009)
parser.parse_player_per_game_data()

# %%
parser = NBAParser(year=2009)
parser.parse_player_per_game_data()

# %%
driver = webdriver.Firefox(executable_path="C:/Users/rivverg/DontBeABitch/Projects/My Shit/basketball-betting-ml/src/dependencies/geckodriver.exe")

# %%
year = 2009
driver.get('https://www.basketball-reference.com/leagues/NBA_{}_per_game.html'.format(year))
driver.execute_script("window.scrollTo(1,1000)")
time.sleep(2)

# %%
html = driver.page_source

# %%
with open("data/raw_data/player_per_game_html/{}.html".format(year), "w+", encoding="utf-8") as f:
    f.write(html)

# %%
pg = []
for year in list(range(1991, 2023)):
    parser = NBAParser(year)
    pg.append(parser.parse_player_per_game_html())
    
df = pd.concat(pg)
df.to_csv("not_raw_data/per_game_stats/basic_per_game_stats.csv")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [2], in <cell line: 2>()
#       2 for year in list(range(1991, 2023)):
#       3     parser = NBAParser(year)
# ----> 4     pg.append(parser.parse_player_per_game_html())
#       6 df = pd.concat(pg)
#       7 df.to_csv("not_raw_data/per_game_stats/basic_per_game_stats.csv")
#
# File ~\DontBeABitch\Projects\My Shit\basketball-betting-ml\src\develop.py:40, in NBAParser.parse_player_per_game_html(self)
#      37 with open(f"data/raw_data/player_per_game_html/{self.year}.html", "r", encoding="utf-8") as f:
#      38     page = f.read()
# ---> 40 per_game_table = self.drop_extra_headers(page_=page, name_="tr", class_="thead", id_="per_game_stats")
#      42 per_game = pd.read_html(str(per_game_table))[0].assign(Year=self.year)
#      44 return per_game
#
# File ~\DontBeABitch\Projects\My Shit\basketball-betting-ml\src\develop.py:64, in NBAParser.drop_extra_headers(page_, name_, class_, id_)
#      61 @staticmethod
#      62 def drop_extra_headers(page_, name_, class_, id_):
#      63     soup = BeautifulSoup(page_, "html.parser")
# ---> 64     soup.find(name=name_, class_=class_).decompose()
#      65     table = soup.find(id=id_)
#      66     return table
#
# AttributeError: 'NoneType' object has no attribute 'decompose'

# %%
year=2009
with open("data/raw_data/player_per_game_html/{}.html".format(year), "r", encoding="utf-8") as f:
    page = f.read()
  


soup = BeautifulSoup(page, "html.parser")
soup.find("tr", class_="thead").decompose()
per_game_table = soup.find(id="per_game_stats")

player_table = pd.read_html(str(per_game_table))
player_table
# Out:
# [      Rk           Player Pos Age   Tm   G  GS    MP   FG   FGA  ...   FT%  \
#  0      1       Alex Acker  SG  26  TOT  25   0   8.0  1.2   3.0  ...  .500
#  1      1       Alex Acker  SG  26  DET   7   0   2.9  0.6   1.6  ...  .500
#  2      1       Alex Acker  SG  26  LAC  18   0   9.9  1.4   3.6  ...  .500
#  3      2     Hassan Adams  SG  24  TOR  12   0   4.3  0.3   1.1  ...  .500
#  4      3    Arron Afflalo  SG  23  DET  74   8  16.7  1.8   4.1  ...  .817
#  ..   ...              ...  ..  ..  ...  ..  ..   ...  ...   ...  ...   ...
#  598  441    Julian Wright  SF  21  NOH  54  19  14.3  2.0   4.3  ...  .567
#  599  442  Lorenzen Wright   C  33  CLE  17   2   7.4  0.6   1.6  ...  .375
#  600  443       Nick Young  SG  23  WAS  82   5  22.4  4.1   9.2  ...  .850
#  601  444   Thaddeus Young  PF  20  PHI  75  71  34.4  6.3  12.8  ...  .735
#  602  445          Sun Yue  SG  23  LAL  10   0   2.8  0.3   1.1  ...   NaN
#
#       ORB  DRB  TRB  AST  STL  BLK  TOV   PF   PTS
#  0    0.3  0.6  1.0  0.5  0.2  0.2  0.3  0.4   2.9
#  1    0.0  0.3  0.3  0.1  0.3  0.1  0.0  0.0   1.3
#  2    0.4  0.8  1.2  0.6  0.2  0.2  0.4  0.5   3.5
#  3    0.1  0.5  0.6  0.1  0.1  0.1  0.3  0.3   0.9
#  4    0.4  1.4  1.8  0.6  0.4  0.2  0.6  1.9   4.9
#  ..   ...  ...  ...  ...  ...  ...  ...  ...   ...
#  598  0.9  2.0  2.8  0.8  0.6  0.4  0.8  0.9   4.4
#  599  0.4  1.1  1.5  0.2  0.2  0.3  0.5  1.0   1.4
#  600  0.4  1.5  1.8  1.2  0.5  0.2  1.1  1.7  10.9
#  601  1.9  3.2  5.0  1.1  1.3  0.3  1.6  2.2  15.3
#  602  0.0  0.0  0.0  0.2  0.1  0.1  0.3  1.0   0.6
#
#  [603 rows x 30 columns]]

# %%
df.to_csv("data/not_raw_data/mvp_voting/mvp_voting.csv")

# %%
players = NBAPlayers(year=1991)
players.player_identifiers
# Out:
# 0      abdelal01
# 1      abdulma02
# 2      acresma01
# 3      adamsmi01
# 4      aguirma01
#          ...
# 410    wrighho02
# 411    wrighho02
# 412    wrighho02
# 413    wyndeaj01
# 414    youngda01
# Name: slug, Length: 415, dtype: object

# %%
adv_stats = players.advanced_stats
adv_stats[adv_stats['name'] == 'Michael Jordan'].columns
# Out:
# Index(['slug', 'name', 'positions', 'age', 'team', 'games_played',
#        'minutes_played', 'player_efficiency_rating',
#        'true_shooting_percentage', 'three_point_attempt_rate',
#        'free_throw_attempt_rate', 'offensive_rebound_percentage',
#        'defensive_rebound_percentage', 'total_rebound_percentage',
#        'assist_percentage', 'steal_percentage', 'block_percentage',
#        'turnover_percentage', 'usage_percentage', 'offensive_win_shares',
#        'defensive_win_shares', 'win_shares', 'win_shares_per_48_minutes',
#        'offensive_box_plus_minus', 'defensive_box_plus_minus',
#        'box_plus_minus', 'value_over_replacement_player',
#        'is_combined_totals'],
#       dtype='object')

# %%
game = client.season_schedule(2012)[0]
game
# Out:
# {'start_time': datetime.datetime(2011, 12, 25, 17, 0, tzinfo=<UTC>),
#  'away_team': <Team.BOSTON_CELTICS: 'BOSTON CELTICS'>,
#  'home_team': <Team.NEW_YORK_KNICKS: 'NEW YORK KNICKS'>,
#  'away_team_score': 104,
#  'home_team_score': 106}

# %%
players = NBAPlayers(2009)
client.regular_season_player_box_scores(player_identifier=players.player_identifiers.iloc[0], season_end_year=2009)
# Out:
# [{'date': datetime.date(2008, 11, 3),
#   'team': <Team.DETROIT_PISTONS: 'DETROIT PISTONS'>,
#   'location': <Location.AWAY: 'AWAY'>,
#   'opponent': <Team.CHARLOTTE_BOBCATS: 'CHARLOTTE BOBCATS'>,
#   'outcome': <Outcome.WIN: 'WIN'>,
#   'active': True,
#   'seconds_played': 116,
#   'made_field_goals': 1,
#   'attempted_field_goals': 1,
#   'made_three_point_field_goals': 0,
#   'attempted_three_point_field_goals': 0,
#   'made_free_throws': 0,
#   'attempted_free_throws': 0,
#   'offensive_rebounds': 0,
#   'defensive_rebounds': 1,
#   'assists': 0,
#   'steals': 0,
#   'blocks': 0,
#   'turnovers': 0,
#   'personal_fouls': 0,
#   'points_scored': 2,
#   'game_score': 2.0,
#   'plus_minus': 3},
#  {'date': datetime.date(2008, 11, 5),
#   'team': <Team.DETROIT_PISTONS: 'DETROIT PISTONS'>,
#   'location': <Location.AWAY: 'AWAY'>,
#   'opponent': <Team.TORONTO_RAPTORS: 'TORONTO RAPTORS'>,
#   'outcome': <Outcome.WIN: 'WIN'>,
#   'active': True,
#   'seconds_played': 300,
#   'made_field_goals': 0,
#   'attempted_field_goals': 1,
#   'made_three_point_field_goals': 0,
#   'attempted_three_point_field_goals': 1,
#   'made_free_throws': 0,
#   'attempted_free_throws': 0,
#   'offensive_rebounds': 0,
#   'defensive_rebounds': 0,
#   'assists': 1,
#   'steals': 0,
#   'blocks': 0,
#   'turnovers': 0,
#   'personal_fouls': 0,
#   'points_scored': 0,
#   'game_score': 0.0,
#   'plus_minus': -1},
#  {'date': datetime.date(2008, 11, 16),
#   'team': <Team.DETROIT_PISTONS: 'DETROIT PISTONS'>,
#   'location': <Location.AWAY: 'AWAY'>,
#   'opponent': <Team.PHOENIX_SUNS: 'PHOENIX SUNS'>,
#   'outcome': <Outcome.LOSS: 'LOSS'>,
#   'active': True,
#   'seconds_played': 186,
#   'made_field_goals': 0,
#   'attempted_field_goals': 1,
#   'made_three_point_field_goals': 0,
#   'attempted_three_point_field_goals': 1,
#   'made_free_throws': 1,
#   'attempted_free_throws': 2,
#   'offensive_rebounds': 0,
#   'defensive_rebounds': 0,
#   'assists': 0,
#   'steals': 1,
#   'blocks': 0,
#   'turnovers': 0,
#   'personal_fouls': 0,
#   'points_scored': 1,
#   'game_score': 0.9,
#   'plus_minus': 5},
#  {'date': datetime.date(2008, 11, 20),
#   'team': <Team.DETROIT_PISTONS: 'DETROIT PISTONS'>,
#   'location': <Location.AWAY: 'AWAY'>,
#   'opponent': <Team.BOSTON_CELTICS: 'BOSTON CELTICS'>,
#   'outcome': <Outcome.LOSS: 'LOSS'>,
#   'active': True,
#   'seconds_played': 191,
#   'made_field_goals': 1,
#   'attempted_field_goals': 3,
#   'made_three_point_field_goals': 0,
#   'attempted_three_point_field_goals': 1,
#   'made_free_throws': 0,
#   'attempted_free_throws': 0,
#   'offensive_rebounds': 0,
#   'defensive_rebounds': 0,
#   'assists': 0,
#   'steals': 1,
#   'blocks': 0,
#   'turnovers': 0,
#   'personal_fouls': 0,
#   'points_scored': 2,
#   'game_score': 1.3,
#   'plus_minus': 2},
#  {'date': datetime.date(2008, 11, 23),
#   'team': <Team.DETROIT_PISTONS: 'DETROIT PISTONS'>,
#   'location': <Location.HOME: 'HOME'>,
#   'opponent': <Team.MINNESOTA_TIMBERWOLVES: 'MINNESOTA TIMBERWOLVES'>,
#   'outcome': <Outcome.LOSS: 'LOSS'>,
#   'active': True,
#   'seconds_played': 120,
#   'made_field_goals': 1,
#   'attempted_field_goals': 2,
#   'made_three_point_field_goals': 0,
#   'attempted_three_point_field_goals': 0,
#   'made_free_throws': 0,
#   'attempted_free_throws': 0,
#   'offensive_rebounds': 0,
#   'defensive_rebounds': 1,
#   'assists': 0,
#   'steals': 0,
#   'blocks': 0,
#   'turnovers': 0,
#   'personal_fouls': 0,
#   'points_scored': 2,
#   'game_score': 1.3,
#   'plus_minus': 2},
#  {'date': datetime.date(2008, 12, 31),
#   'team': <Team.DETROIT_PISTONS: 'DETROIT PISTONS'>,
#   'location': <Location.HOME: 'HOME'>,
#   'opponent': <Team.NEW_JERSEY_NETS: 'NEW JERSEY NETS'>,
#   'outcome': <Outcome.WIN: 'WIN'>,
#   'active': True,
#   'seconds_played': 2,
#   'made_field_goals': 0,
#   'attempted_field_goals': 0,
#   'made_three_point_field_goals': 0,
#   'attempted_three_point_field_goals': 0,
#   'made_free_throws': 0,
#   'attempted_free_throws': 0,
#   'offensive_rebounds': 0,
#   'defensive_rebounds': 0,
#   'assists': 0,
#   'steals': 0,
#   'blocks': 0,
#   'turnovers': 0,
#   'personal_fouls': 0,
#   'points_scored': 0,
#   'game_score': 0.0,
#   'plus_minus': -1},
#  {'date': datetime.date(2009, 1, 10),
#   'team': <Team.DETROIT_PISTONS: 'DETROIT PISTONS'>,
#   'location': <Location.AWAY: 'AWAY'>,
#   'opponent': <Team.UTAH_JAZZ: 'UTAH JAZZ'>,
#   'outcome': <Outcome.LOSS: 'LOSS'>,
#   'active': True,
#   'seconds_played': 313,
#   'made_field_goals': 1,
#   'attempted_field_goals': 3,
#   'made_three_point_field_goals': 0,
#   'attempted_three_point_field_goals': 1,
#   'made_free_throws': 0,
#   'attempted_free_throws': 0,
#   'offensive_rebounds': 0,
#   'defensive_rebounds': 0,
#   'assists': 0,
#   'steals': 0,
#   'blocks': 1,
#   'turnovers': 0,
#   'personal_fouls': 0,
#   'points_scored': 2,
#   'game_score': 1.0,
#   'plus_minus': 8},
#  {'date': datetime.date(2009, 2, 17),
#   'team': <Team.LOS_ANGELES_CLIPPERS: 'LOS ANGELES CLIPPERS'>,
#   'location': <Location.AWAY: 'AWAY'>,
#   'opponent': <Team.PHOENIX_SUNS: 'PHOENIX SUNS'>,
#   'outcome': <Outcome.LOSS: 'LOSS'>,
#   'active': True,
#   'seconds_played': 720,
#   'made_field_goals': 3,
#   'attempted_field_goals': 6,
#   'made_three_point_field_goals': 2,
#   'attempted_three_point_field_goals': 2,
#   'made_free_throws': 2,
#   'attempted_free_throws': 2,
#   'offensive_rebounds': 1,
#   'defensive_rebounds': 1,
#   'assists': 0,
#   'steals': 0,
#   'blocks': 0,
#   'turnovers': 2,
#   'personal_fouls': 0,
#   'points_scored': 10,
#   'game_score': 6.0,
#   'plus_minus': 6},
#  {'date': datetime.date(2009, 2, 22),
#   'team': <Team.LOS_ANGELES_CLIPPERS: 'LOS ANGELES CLIPPERS'>,
#   'location': <Location.AWAY: 'AWAY'>,
#   'opponent': <Team.PORTLAND_TRAIL_BLAZERS: 'PORTLAND TRAIL BLAZERS'>,
#   'outcome': <Outcome.LOSS: 'LOSS'>,
#   'active': True,
#   'seconds_played': 766,
#   'made_field_goals': 1,
#   'attempted_field_goals': 6,
#   'made_three_point_field_goals': 0,
#   'attempted_three_point_field_goals': 2,
#   'made_free_throws': 0,
#   'attempted_free_throws': 2,
#   'offensive_rebounds': 2,
#   'defensive_rebounds': 0,
#   'assists': 0,
#   'steals': 1,
#   'blocks': 0,
#   'turnovers': 0,
#   'personal_fouls': 0,
#   'points_scored': 2,
#   'game_score': -0.2,
#   'plus_minus': -8},
#  {'date': datetime.date(2009, 2, 27),
#   'team': <Team.LOS_ANGELES_CLIPPERS: 'LOS ANGELES CLIPPERS'>,
#   'location': <Location.AWAY: 'AWAY'>,
#   'opponent': <Team.SACRAMENTO_KINGS: 'SACRAMENTO KINGS'>,
#   'outcome': <Outcome.LOSS: 'LOSS'>,
#   'active': True,
#   'seconds_played': 258,
#   'made_field_goals': 2,
#   'attempted_field_goals': 4,
#   'made_three_point_field_goals': 1,
#   'attempted_three_point_field_goals': 1,
#   'made_free_throws': 0,
#   'attempted_free_throws': 0,
#   'offensive_rebounds': 0,
#   'defensive_rebounds': 0,
#   'assists': 0,
#   'steals': 0,
#   'blocks': 0,
#   'turnovers': 0,
#   'personal_fouls': 0,
#   'points_scored': 5,
#   'game_score': 3.0,
#   'plus_minus': 9},
#  {'date': datetime.date(2009, 2, 28),
#   'team': <Team.LOS_ANGELES_CLIPPERS: 'LOS ANGELES CLIPPERS'>,
#   'location': <Location.HOME: 'HOME'>,
#   'opponent': <Team.CHARLOTTE_BOBCATS: 'CHARLOTTE BOBCATS'>,
#   'outcome': <Outcome.LOSS: 'LOSS'>,
#   'active': True,
#   'seconds_played': 796,
#   'made_field_goals': 2,
#   'attempted_field_goals': 3,
#   'made_three_point_field_goals': 1,
#   'attempted_three_point_field_goals': 2,
#   'made_free_throws': 0,
#   'attempted_free_throws': 0,
#   'offensive_rebounds': 0,
#   'defensive_rebounds': 2,
#   'assists': 1,
#   'steals': 0,
#   'blocks': 0,
#   'turnovers': 1,
#   'personal_fouls': 2,
#   'points_scored': 5,
#   'game_score': 3.2,
#   'plus_minus': -5},
#  {'date': datetime.date(2009, 3, 2),
#   'team': <Team.LOS_ANGELES_CLIPPERS: 'LOS ANGELES CLIPPERS'>,
#   'location': <Location.HOME: 'HOME'>,
#   'opponent': <Team.SAN_ANTONIO_SPURS: 'SAN ANTONIO SPURS'>,
#   'outcome': <Outcome.LOSS: 'LOSS'>,
#   'active': True,
#   'seconds_played': 604,
#   'made_field_goals': 0,
#   'attempted_field_goals': 4,
#   'made_three_point_field_goals': 0,
#   'attempted_three_point_field_goals': 1,
#   'made_free_throws': 0,
#   'attempted_free_throws': 0,
#   'offensive_rebounds': 1,
#   'defensive_rebounds': 1,
#   'assists': 0,
#   'steals': 0,
#   'blocks': 0,
#   'turnovers': 1,
#   'personal_fouls': 2,
#   'points_scored': 0,
#   'game_score': -3.6,
#   'plus_minus': -16},
#  {'date': datetime.date(2009, 3, 4),
#   'team': <Team.LOS_ANGELES_CLIPPERS: 'LOS ANGELES CLIPPERS'>,
#   'location': <Location.HOME: 'HOME'>,
#   'opponent': <Team.MEMPHIS_GRIZZLIES: 'MEMPHIS GRIZZLIES'>,
#   'outcome': <Outcome.LOSS: 'LOSS'>,
#   'active': True,
#   'seconds_played': 96,
#   'made_field_goals': 1,
#   'attempted_field_goals': 1,
#   'made_three_point_field_goals': 0,
#   'attempted_three_point_field_goals': 0,
#   'made_free_throws': 0,
#   'attempted_free_throws': 0,
#   'offensive_rebounds': 0,
#   'defensive_rebounds': 0,
#   'assists': 0,
#   'steals': 0,
#   'blocks': 0,
#   'turnovers': 0,
#   'personal_fouls': 0,
#   'points_scored': 2,
#   'game_score': 1.7,
#   'plus_minus': -6},
#  {'date': datetime.date(2009, 3, 7),
#   'team': <Team.LOS_ANGELES_CLIPPERS: 'LOS ANGELES CLIPPERS'>,
#   'location': <Location.HOME: 'HOME'>,
#   'opponent': <Team.INDIANA_PACERS: 'INDIANA PACERS'>,
#   'outcome': <Outcome.LOSS: 'LOSS'>,
#   'active': True,
#   'seconds_played': 717,
#   'made_field_goals': 0,
#   'attempted_field_goals': 2,
#   'made_three_point_field_goals': 0,
#   'attempted_three_point_field_goals': 2,
#   'made_free_throws': 0,
#   'attempted_free_throws': 0,
#   'offensive_rebounds': 0,
#   'defensive_rebounds': 0,
#   'assists': 1,
#   'steals': 0,
#   'blocks': 0,
#   'turnovers': 0,
#   'personal_fouls': 2,
#   'points_scored': 0,
#   'game_score': -1.5,
#   'plus_minus': -6},
#  {'date': datetime.date(2009, 3, 14),
#   'team': <Team.LOS_ANGELES_CLIPPERS: 'LOS ANGELES CLIPPERS'>,
#   'location': <Location.AWAY: 'AWAY'>,
#   'opponent': <Team.DENVER_NUGGETS: 'DENVER NUGGETS'>,
#   'outcome': <Outcome.LOSS: 'LOSS'>,
#   'active': True,
#   'seconds_played': 75,
#   'made_field_goals': 0,
#   'attempted_field_goals': 0,
#   'made_three_point_field_goals': 0,
#   'attempted_three_point_field_goals': 0,
#   'made_free_throws': 0,
#   'attempted_free_throws': 0,
#   'offensive_rebounds': 0,
#   'defensive_rebounds': 0,
#   'assists': 0,
#   'steals': 0,
#   'blocks': 0,
#   'turnovers': 0,
#   'personal_fouls': 0,
#   'points_scored': 0,
#   'game_score': 0.0,
#   'plus_minus': 2},
#  {'date': datetime.date(2009, 3, 20),
#   'team': <Team.LOS_ANGELES_CLIPPERS: 'LOS ANGELES CLIPPERS'>,
#   'location': <Location.AWAY: 'AWAY'>,
#   'opponent': <Team.DETROIT_PISTONS: 'DETROIT PISTONS'>,
#   'outcome': <Outcome.LOSS: 'LOSS'>,
#   'active': True,
#   'seconds_played': 36,
#   'made_field_goals': 0,
#   'attempted_field_goals': 0,
#   'made_three_point_field_goals': 0,
#   'attempted_three_point_field_goals': 0,
#   'made_free_throws': 0,
#   'attempted_free_throws': 0,
#   'offensive_rebounds': 0,
#   'defensive_rebounds': 0,
#   'assists': 0,
#   'steals': 0,
#   'blocks': 0,
#   'turnovers': 0,
#   'personal_fouls': 0,
#   'points_scored': 0,
#   'game_score': 0.0,
#   'plus_minus': -2},
#  {'date': datetime.date(2009, 3, 22),
#   'team': <Team.LOS_ANGELES_CLIPPERS: 'LOS ANGELES CLIPPERS'>,
#   'location': <Location.AWAY: 'AWAY'>,
#   'opponent': <Team.TORONTO_RAPTORS: 'TORONTO RAPTORS'>,
#   'outcome': <Outcome.LOSS: 'LOSS'>,
#   'active': True,
#   'seconds_played': 332,
#   'made_field_goals': 0,
#   'attempted_field_goals': 1,
#   'made_three_point_field_goals': 0,
#   'attempted_three_point_field_goals': 0,
#   'made_free_throws': 0,
#   'attempted_free_throws': 2,
#   'offensive_rebounds': 0,
#   'defensive_rebounds': 0,
#   'assists': 1,
#   'steals': 0,
#   'blocks': 0,
#   'turnovers': 1,
#   'personal_fouls': 0,
#   'points_scored': 0,
#   'game_score': -1.8,
#   'plus_minus': 2},
#  {'date': datetime.date(2009, 3, 27),
#   'team': <Team.LOS_ANGELES_CLIPPERS: 'LOS ANGELES CLIPPERS'>,
#   'location': <Location.AWAY: 'AWAY'>,
#   'opponent': <Team.SAN_ANTONIO_SPURS: 'SAN ANTONIO SPURS'>,
#   'outcome': <Outcome.LOSS: 'LOSS'>,
#   'active': True,
#   'seconds_played': 1019,
#   'made_field_goals': 2,
#   'attempted_field_goals': 6,
#   'made_three_point_field_goals': 0,
#   'attempted_three_point_field_goals': 1,
#   'made_free_throws': 0,
#   'attempted_free_throws': 0,
#   'offensive_rebounds': 3,
#   'defensive_rebounds': 5,
#   'assists': 2,
#   'steals': 0,
#   'blocks': 1,
#   'turnovers': 0,
#   'personal_fouls': 0,
#   'points_scored': 4,
#   'game_score': 6.3,
#   'plus_minus': 11},
#  {'date': datetime.date(2009, 3, 28),
#   'team': <Team.LOS_ANGELES_CLIPPERS: 'LOS ANGELES CLIPPERS'>,
#   'location': <Location.AWAY: 'AWAY'>,
#   'opponent': <Team.HOUSTON_ROCKETS: 'HOUSTON ROCKETS'>,
#   'outcome': <Outcome.LOSS: 'LOSS'>,
#   'active': True,
#   'seconds_played': 773,
#   'made_field_goals': 2,
#   'attempted_field_goals': 3,
#   'made_three_point_field_goals': 0,
#   'attempted_three_point_field_goals': 0,
#   'made_free_throws': 0,
#   'attempted_free_throws': 0,
#   'offensive_rebounds': 1,
#   'defensive_rebounds': 1,
#   'assists': 2,
#   'steals': 0,
#   'blocks': 0,
#   'turnovers': 1,
#   'personal_fouls': 2,
#   'points_scored': 4,
#   'game_score': 3.3,
#   'plus_minus': 5},
#  {'date': datetime.date(2009, 4, 4),
#   'team': <Team.LOS_ANGELES_CLIPPERS: 'LOS ANGELES CLIPPERS'>,
#   'location': <Location.AWAY: 'AWAY'>,
#   'opponent': <Team.DENVER_NUGGETS: 'DENVER NUGGETS'>,
#   'outcome': <Outcome.LOSS: 'LOSS'>,
#   'active': True,
#   'seconds_played': 672,
#   'made_field_goals': 4,
#   'attempted_field_goals': 7,
#   'made_three_point_field_goals': 2,
#   'attempted_three_point_field_goals': 2,
#   'made_free_throws': 0,
#   'attempted_free_throws': 0,
#   'offensive_rebounds': 0,
#   'defensive_rebounds': 1,
#   'assists': 0,
#   'steals': 0,
#   'blocks': 1,
#   'turnovers': 0,
#   'personal_fouls': 0,
#   'points_scored': 10,
#   'game_score': 7.7,
#   'plus_minus': 8},
#  {'date': datetime.date(2009, 4, 7),
#   'team': <Team.LOS_ANGELES_CLIPPERS: 'LOS ANGELES CLIPPERS'>,
#   'location': <Location.HOME: 'HOME'>,
#   'opponent': <Team.MINNESOTA_TIMBERWOLVES: 'MINNESOTA TIMBERWOLVES'>,
#   'outcome': <Outcome.LOSS: 'LOSS'>,
#   'active': True,
#   'seconds_played': 682,
#   'made_field_goals': 1,
#   'attempted_field_goals': 4,
#   'made_three_point_field_goals': 0,
#   'attempted_three_point_field_goals': 1,
#   'made_free_throws': 0,
#   'attempted_free_throws': 0,
#   'offensive_rebounds': 0,
#   'defensive_rebounds': 0,
#   'assists': 0,
#   'steals': 1,
#   'blocks': 0,
#   'turnovers': 0,
#   'personal_fouls': 0,
#   'points_scored': 2,
#   'game_score': 0.6,
#   'plus_minus': -4},
#  {'date': datetime.date(2009, 4, 10),
#   'team': <Team.LOS_ANGELES_CLIPPERS: 'LOS ANGELES CLIPPERS'>,
#   'location': <Location.HOME: 'HOME'>,
#   'opponent': <Team.SACRAMENTO_KINGS: 'SACRAMENTO KINGS'>,
#   'outcome': <Outcome.WIN: 'WIN'>,
#   'active': True,
#   'seconds_played': 1107,
#   'made_field_goals': 5,
#   'attempted_field_goals': 8,
#   'made_three_point_field_goals': 1,
#   'attempted_three_point_field_goals': 2,
#   'made_free_throws': 0,
#   'attempted_free_throws': 0,
#   'offensive_rebounds': 0,
#   'defensive_rebounds': 1,
#   'assists': 3,
#   'steals': 0,
#   'blocks': 0,
#   'turnovers': 0,
#   'personal_fouls': 0,
#   'points_scored': 11,
#   'game_score': 9.8,
#   'plus_minus': 6},
#  {'date': datetime.date(2009, 4, 11),
#   'team': <Team.LOS_ANGELES_CLIPPERS: 'LOS ANGELES CLIPPERS'>,
#   'location': <Location.HOME: 'HOME'>,
#   'opponent': <Team.PORTLAND_TRAIL_BLAZERS: 'PORTLAND TRAIL BLAZERS'>,
#   'outcome': <Outcome.LOSS: 'LOSS'>,
#   'active': True,
#   'seconds_played': 587,
#   'made_field_goals': 0,
#   'attempted_field_goals': 4,
#   'made_three_point_field_goals': 0,
#   'attempted_three_point_field_goals': 0,
#   'made_free_throws': 2,
#   'attempted_free_throws': 2,
#   'offensive_rebounds': 0,
#   'defensive_rebounds': 0,
#   'assists': 0,
#   'steals': 1,
#   'blocks': 0,
#   'turnovers': 0,
#   'personal_fouls': 0,
#   'points_scored': 2,
#   'game_score': 0.2,
#   'plus_minus': -4},
#  {'date': datetime.date(2009, 4, 13),
#   'team': <Team.LOS_ANGELES_CLIPPERS: 'LOS ANGELES CLIPPERS'>,
#   'location': <Location.AWAY: 'AWAY'>,
#   'opponent': <Team.UTAH_JAZZ: 'UTAH JAZZ'>,
#   'outcome': <Outcome.LOSS: 'LOSS'>,
#   'active': True,
#   'seconds_played': 465,
#   'made_field_goals': 0,
#   'attempted_field_goals': 1,
#   'made_three_point_field_goals': 0,
#   'attempted_three_point_field_goals': 0,
#   'made_free_throws': 0,
#   'attempted_free_throws': 0,
#   'offensive_rebounds': 0,
#   'defensive_rebounds': 1,
#   'assists': 1,
#   'steals': 0,
#   'blocks': 0,
#   'turnovers': 0,
#   'personal_fouls': 0,
#   'points_scored': 0,
#   'game_score': 0.3,
#   'plus_minus': -4},
#  {'date': datetime.date(2009, 4, 15),
#   'team': <Team.LOS_ANGELES_CLIPPERS: 'LOS ANGELES CLIPPERS'>,
#   'location': <Location.HOME: 'HOME'>,
#   'opponent': <Team.OKLAHOMA_CITY_THUNDER: 'OKLAHOMA CITY THUNDER'>,
#   'outcome': <Outcome.LOSS: 'LOSS'>,
#   'active': True,
#   'seconds_played': 1042,
#   'made_field_goals': 3,
#   'attempted_field_goals': 5,
#   'made_three_point_field_goals': 0,
#   'attempted_three_point_field_goals': 0,
#   'made_free_throws': 0,
#   'attempted_free_throws': 0,
#   'offensive_rebounds': 0,
#   'defensive_rebounds': 1,
#   'assists': 0,
#   'steals': 0,
#   'blocks': 1,
#   'turnovers': 1,
#   'personal_fouls': 1,
#   'points_scored': 6,
#   'game_score': 3.3,
#   'plus_minus': -11}]

# %%
players.player_identifiers.iloc[0]
# Out:
# 'ackeral01'

# %%
players.advanced_stats.iloc[0]
# Out:
# slug                                             ackeral01
# name                                            Alex Acker
# positions                        [Position.SHOOTING_GUARD]
# age                                                     26
# team                                  Team.DETROIT_PISTONS
# games_played                                             7
# minutes_played                                          20
# player_efficiency_rating                              16.0
# true_shooting_percentage                             0.379
# three_point_attempt_rate                             0.364
# free_throw_attempt_rate                              0.182
# offensive_rebound_percentage                           0.0
# defensive_rebound_percentage                          12.0
# total_rebound_percentage                               5.9
# assist_percentage                                      9.1
# steal_percentage                                       5.5
# block_percentage                                       3.9
# turnover_percentage                                    0.0
# usage_percentage                                      28.3
# offensive_win_shares                                   0.0
# defensive_win_shares                                   0.0
# win_shares                                             0.0
# win_shares_per_48_minutes                            0.009
# offensive_box_plus_minus                              -0.9
# defensive_box_plus_minus                               4.7
# box_plus_minus                                         3.8
# value_over_replacement_player                          0.0
# is_combined_totals                                   False
# Name: 0, dtype: object

# %%
pd.DataFrame(client.players_advanced_season_totals(2012))
# Out:
#           slug            name                  positions  age  \
# 0    adrieje01     Jeff Adrien   [Position.POWER_FORWARD]   25
# 1    afflaar01   Arron Afflalo  [Position.SHOOTING_GUARD]   26
# 2    ahearbl01    Blake Ahearn     [Position.POINT_GUARD]   27
# 3    alabiso01   Solomon Alabi          [Position.CENTER]   23
# 4    aldrico01    Cole Aldrich          [Position.CENTER]   23
# ..         ...             ...                        ...  ...
# 510  youngni01      Nick Young  [Position.SHOOTING_GUARD]   26
# 511  youngni01      Nick Young  [Position.SHOOTING_GUARD]   26
# 512  youngsa01       Sam Young   [Position.SMALL_FORWARD]   26
# 513  youngsa01       Sam Young   [Position.SMALL_FORWARD]   26
# 514  youngth01  Thaddeus Young   [Position.POWER_FORWARD]   23
#
#                            team  games_played  minutes_played  \
# 0          Team.HOUSTON_ROCKETS             8              63
# 1           Team.DENVER_NUGGETS            62            2086
# 2                Team.UTAH_JAZZ             4              30
# 3          Team.TORONTO_RAPTORS            14             122
# 4    Team.OKLAHOMA_CITY_THUNDER            26             173
# ..                          ...           ...             ...
# 510     Team.WASHINGTON_WIZARDS            40            1211
# 511   Team.LOS_ANGELES_CLIPPERS            22             518
# 512      Team.MEMPHIS_GRIZZLIES            21             240
# 513     Team.PHILADELPHIA_76ERS            14             135
# 514     Team.PHILADELPHIA_76ERS            63            1755
#
#      player_efficiency_rating  true_shooting_percentage  \
# 0                        11.2                     0.493
# 1                        14.7                     0.584
# 2                        -7.3                     0.357
# 3                        14.2                     0.418
# 4                        17.7                     0.592
# ..                        ...                       ...
# 510                      14.2                     0.513
# 511                       9.9                     0.509
# 512                      10.6                     0.419
# 513                       8.2                     0.399
# 514                      18.9                     0.538
#
#      three_point_attempt_rate  ...  usage_percentage  offensive_win_shares  \
# 0                       0.000  ...              16.8                   0.1
# 1                       0.316  ...              19.1                   4.7
# 2                       0.643  ...              28.4                  -0.2
# 3                       0.000  ...              17.2                   0.0
# 4                       0.000  ...              14.9                   0.3
# ..                        ...  ...               ...                   ...
# 510                     0.333  ...              26.1                   1.1
# 511                     0.440  ...              20.9                   0.2
# 512                     0.108  ...              18.4                  -0.1
# 513                     0.182  ...              19.9                  -0.2
# 514                     0.006  ...              21.5                   3.4
#
#      defensive_win_shares  win_shares  win_shares_per_48_minutes  \
# 0                     0.1         0.1                      0.106
# 1                     0.6         5.3                      0.121
# 2                     0.0        -0.2                     -0.315
# 3                     0.2         0.2                      0.083
# 4                     0.4         0.6                      0.176
# ..                    ...         ...                        ...
# 510                   0.4         1.5                      0.059
# 511                   0.2         0.4                      0.040
# 512                   0.3         0.2                      0.042
# 513                   0.2         0.0                      0.010
# 514                   2.9         6.3                      0.171
#
#      offensive_box_plus_minus  defensive_box_plus_minus  box_plus_minus  \
# 0                        -4.0                      -0.2            -4.3
# 1                         1.4                      -1.2             0.1
# 2                       -12.7                      -6.8           -19.5
# 3                        -2.9                       0.7            -2.2
# 4                        -1.3                       2.2             1.0
# ..                        ...                       ...             ...
# 510                       0.6                      -2.3            -1.7
# 511                      -2.3                      -1.8            -4.1
# 512                      -2.3                       0.5            -1.8
# 513                      -3.9                       0.7            -3.2
# 514                       1.4                       0.6             2.0
#
#      value_over_replacement_player  is_combined_totals
# 0                              0.0               False
# 1                              1.1               False
# 2                             -0.1               False
# 3                              0.0               False
# 4                              0.1               False
# ..                             ...                 ...
# 510                            0.1               False
# 511                           -0.3               False
# 512                            0.0               False
# 513                            0.0               False
# 514                            1.8               False
#
# [515 rows x 28 columns]
